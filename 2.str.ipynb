# %% [markdown]
# # String:
#
#       - strings are used in python to store text information such as names
#       - it may be word , phrase,sentence ,paragraph,or an entire encyclopedia

# %% [markdown]
# # How to create the string ?
#
#      - to create string in python , we need to use either single quotes or double quotes or triple quotes

# %%
x="john"


x='john'

x
# Out:
# 'john'

# %%
y="manisha"

y
# Out:
# 'manisha'

# %%
sen='deeplearning is heart of generativeai'

sen
# Out:
# 'deeplearning is heart of generativeai'

# %%
type(sen)
# Out:
# str

# %%
x='I'm ravi , i want to become a datascientist'


x
# Out:
#   Cell In[5], line 1
#     x='I'm ravi , i want to become a datascientist'
#                                                   ^
# SyntaxError: unterminated string literal (detected at line 1)

# %%
x="I'm ravi , i want to become a datascientist"


x
# Out:
# "I'm ravi , i want to become a datascientist"

# %%
z='Artificial General Intelligence (AGI) refers to AI systems capable of performing a wide range of intellectual tasks like humans.
Unlike narrow AI, AGI would not be limited to one specific task or domain.
It could learn, reason, understand, solve problems, and adapt to new situations.
AGI is expected to transfer knowledge learned in one area to another area.
For example, an AGI system could learn programming, analyze medical data, write reports, and learn new skills.
True AGI has not yet been achieved, and it remains an active area of AI research'


print(z)
# Out:
#   Cell In[9], line 1
#     z='Artificial General Intelligence (AGI) refers to AI systems capable of performing a wide range of intellectual tasks like humans.
#       ^
# SyntaxError: unterminated string literal (detected at line 1)

# %%
z="Artificial General Intelligence (AGI) refers to AI systems capable of performing a wide range of intellectual tasks like humans.
Unlike narrow AI, AGI would not be limited to one specific task or domain.
It could learn, reason, understand, solve problems, and adapt to new situations.
AGI is expected to transfer knowledge learned in one area to another area.
For example, an AGI system could learn programming, analyze medical data, write reports, and learn new skills.
True AGI has not yet been achieved, and it remains an active area of AI research"


z
# Out:
#   Cell In[10], line 1
#     z="Artificial General Intelligence (AGI) refers to AI systems capable of performing a wide range of intellectual tasks like humans.
#       ^
# SyntaxError: unterminated string literal (detected at line 1)

# %%
z="""Artificial General Intelligence (AGI) refers to AI systems capable of performing a wide range of intellectual tasks like humans.
Unlike narrow AI, AGI would not be limited to one specific task or domain.
It could learn, reason, understand, solve problems, and adapt to new situations.
AGI is expected to transfer knowledge learned in one area to another area.
For example, an AGI system could learn programming, analyze medical data, write reports, and learn new skills.
True AGI has not yet been achieved, and it remains an active area of AI research   
"""



print(z)
# Out:
# Artificial General Intelligence (AGI) refers to AI systems capable of performing a wide range of intellectual tasks like humans.
# Unlike narrow AI, AGI would not be limited to one specific task or domain.
# It could learn, reason, understand, solve problems, and adapt to new situations.
# AGI is expected to transfer knowledge learned in one area to another area.
# For example, an AGI system could learn programming, analyze medical data, write reports, and learn new skills.
# True AGI has not yet been achieved, and it remains an active area of AI research

# %% [markdown]
# # which quotes important ?

# %% [markdown]
#      - the double quotes are more important than single quotes
#
#         - the triple quotes are morethan important than double quotes while using for paragrphas

# %% [markdown]
# # string is  mutable or immutable ?
#
#      - string is immutable , means if once you have created , you can't change means you can delete n add or you can't replace as permenantly  that is called immutable

# %%
a="Hello"

a[0]="C"
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# Cell In[12], line 3
#       1 a="Hello"
#       2
# ----> 3 a[0]="C"
#
# TypeError: 'str' object does not support item assignment

# %%
a.replace("H","C")
# Out:
# 'Cello'

# %%
a
# Out:
# 'Hello'

# %% [markdown]
# - print():
#
#     - print statement to print the multiple inputs

# %%
print(a)
# Out:
# Hello

# %%
p="ravi"

q="hyderabad"

r="clri"


p
q
r
# Out:
# 'clri'

# %%
print(p)

print(q)
print()
print(r)
# Out:
# ravi
# hyderabad
#
# clri

# %%
# the print statement each value separated by comma into space by default (if you want use parameter as separataor sep=" ")
print("hello",1,3,8,0,4,True,False)
# Out:
# hello 1 3 8 0 4 True False

# %%
print("hello",1,3,8,0,4,True,False,sep=" ")
# Out:
# hello 1 3 8 0 4 True False

# %%
print("hello",1,3,8,0,4,True,False,sep=",")
# Out:
# hello,1,3,8,0,4,True,False

# %%
print("hello",1,3,8,0,4,True,False,sep="@#")
# Out:
# hello@#1@#3@#8@#0@#4@#True@#False

# %%
print("manisha")

print("bhavana")
# Out:
# manisha
# bhavana

# %%
print("manisha",end=" ")

print("bhavana")
# Out:
# manisha bhavana

# %%
print("manisha",end="*")

print("bhavana")
# Out:
# manisha*bhavana

# %%
print("manisha",end="+")

print("bhavana")
# Out:
# manisha+bhavana

# %%
x="python"
y="is"
z="awesome"


print(x+y+z)
# Out:
# pythonisawesome

# %%
x="python"
y="is"
z=55

print(x+y+z)
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# Cell In[35], line 5
#       1 x="python"
#       2 y="is"
#       3 z=55
#       4
# ----> 5 print(x+y+z)
#
# TypeError: can only concatenate str (not "int") to str

# %% [markdown]
# # - String indexing
#
# - postive index / forward index
#     - left to right
#      - the number has been start from 0 , 1,2,3...
#
#
#
# negative index / backward index
#
# - right to left
# the number has been start from -1 ,-2,-3 ....

# %%
a= "datascience"

a[2]
# Out:
# 't'

# %%
a[4]
# Out:
# 's'

# %%
a[6]
# Out:
# 'i'

# %%
a[8]
# Out:
# 'n'

# %%
a
# Out:
# 'datascience'

# %%
b="bhavana"

# %%
b[3]
# Out:
# 'v'

# %%
b[1]
# Out:
# 'h'

# %%
c="manisha"

# %%
c[-4]
# Out:
# 'i'

# %%
c[-5]
# Out:
# 'n'

# %%
c[-7]
# Out:
# 'm'

# %%
d="artificial inteligence"

# %%
d[10]
# Out:
# ' '

# %%
d[-12]
# Out:
# ' '

# %%
print(d[4])


print(d[-18])
# Out:
# f
# f

# %%
d
# Out:
# 'artificial inteligence'

# %%
print(d[9])


print(d[-13])
# Out:
# l
# l

# %% [markdown]
# # - String slicing
#
# - postive slicing / forward slicing
#     - left to right
#      - the slicing has format [start : stop]
#      the default starting value 0
#
#      the stop value alwyas exlude ( n-1 )
#      [2:5]
#      2,3,4

# %%
x="datascience"

# %%
x[:]
# Out:
# 'datascience'

# %%
x[0:11]
# Out:
# 'datascience'

# %%
x[0:]
# Out:
# 'datascience'

# %%
x[:11]
# Out:
# 'datascience'

# %%
x[ 0 :  4]
# Out:
# 'data'

# %%
x[  4  :11   ]
# Out:
# 'science'

# %%
x[ 2 : 5  ]
# Out:
# 'tas'

# %%
x
# Out:
# 'datascience'

# %%
x[   5  : 8   ]
# Out:
# 'cie'

# %%
p="bhavana"

# %%
p[    3:8   ]
# Out:
# 'vana'

# %%
p[  0 : 5  ]
# Out:
# 'bhava'

# %%
q="manisha"

# %%
q[  3 : 7  ]
# Out:
# 'isha'

# %%
q[ 0 : 3]
# Out:
# 'man'

# %%
q[  2: 7 ]
# Out:
# 'nisha'

# %%
q[  1 : 7 ]
# Out:
# 'anisha'

# %%
r="a famous or important person"

# %%
r[  2  :  8 ]
# Out:
# 'famous'

# %%
r[ 12 : 21 ]
# Out:
# 'important'

# %%
r[ 22 :28   ]
# Out:
# 'person'

# %%
r
# Out:
# 'a famous or important person'

# %%
r[ 9  : 11  ]
# Out:
# 'or'
