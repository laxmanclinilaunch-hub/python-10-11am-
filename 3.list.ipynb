# %% [markdown]
# # list:
#
#
# - list are constructed by [ ]
# -  and each element/ item separated by commas
# - lists are mutable

# %%
a=["bhavana" ,"manisha", 2 , 6.6 , 4+8j  , True , False  , "ravi" ]

# %%
a
# Out:
# ['bhavana', 'manisha', 2, 6.6, (4+8j), True, False, 'ravi']

# %% [markdown]
# - iNDEXING
#
#   - Positive index / +ve index / forward index
#        - it start from 0,1,2,3....
#        - it start from left to right
#        - each item has one index

# %%
a[1]
# Out:
# 'manisha'

# %%
a[0]
# Out:
# 'bhavana'

# %%
a[7]
# Out:
# 'ravi'

# %%
a[4]
# Out:
# (4+8j)

# %% [markdown]
# - negative index / backward index
#
#     - it start from -1,-2,-3....
#     - it start  from  right to left
#     - each item has one index

# %%
a
# Out:
# ['bhavana', 'manisha', 2, 6.6, (4+8j), True, False, 'ravi']

# %%
a[-4]
# Out:
# (4+8j)

# %%
a[-7]
# Out:
# 'manisha'

# %%
a[-6]
# Out:
# 2

# %%
a[-1]
# Out:
# 'ravi'

# %%
a[-3]
# Out:
# True

# %% [markdown]
# - slicing
#
#   - (+ve) postive slicing / forward slicing:
#
#           - it has start and  stop (n-1)
#           - it start from left to right

# %%
a
# Out:
# ['bhavana', 'manisha', 2, 6.6, (4+8j), True, False, 'ravi']

# %%
a[0:4]
# Out:
# ['bhavana', 'manisha', 2, 6.6]

# %%
a[1:6]
# Out:
# ['manisha', 2, 6.6, (4+8j), True]

# %%
a[2 :8 ]
# Out:
# [2, 6.6, (4+8j), True, False, 'ravi']

# %% [markdown]
# - - ve sclicing or backward sclicing
#
#
#   start : stop (n-1)

# %%
a=['bhavana', 'manisha', 2, 6.6, (4+8j), True, False, 'ravi']
a
# Out:
# ['bhavana', 'manisha', 2, 6.6, (4+8j), True, False, 'ravi']

# %%
a[-8:-6]
# Out:
# ['bhavana', 'manisha']

# %%
a[-8:-5]
# Out:
# ['bhavana', 'manisha', 2]

# %%
a[  -3: -1   ]
# Out:
# [True, False]

# %%
a
# Out:
# ['bhavana', 'manisha', 2, 6.6, (4+8j), True, False, 'ravi']

# %%
a[ -6 : -3  ]
# Out:
# [2, 6.6, (4+8j)]

# %% [markdown]
# +ve & -ve slicing with step

# %%
a
# Out:
# ['bhavana', 'manisha', 2, 6.6, (4+8j), True, False, 'ravi']

# %%
a[ 0 :8  ]
# Out:
# ['bhavana', 'manisha', 2, 6.6, (4+8j), True, False, 'ravi']

# %%
a[ 0 :8  : 1 ]
# Out:
# ['bhavana', 'manisha', 2, 6.6, (4+8j), True, False, 'ravi']

# %%
a[ 0 :8  : 2 ]
# Out:
# ['bhavana', 2, (4+8j), False]

# %%
a[ 0 :8  : 3 ]
# Out:
# ['bhavana', 6.6, False]

# %%
a[ 0 :8  : -1 ]
# Out:
# []

# %%
a
# Out:
# ['bhavana', 'manisha', 2, 6.6, (4+8j), True, False, 'ravi']

# %%
a[-8:]
# Out:
# ['bhavana', 'manisha', 2, 6.6, (4+8j), True, False, 'ravi']

# %%
a[-8:-1]
# Out:
# ['bhavana', 'manisha', 2, 6.6, (4+8j), True, False]

# %%
a[-8:-1 : ]
# Out:
# ['bhavana', 'manisha', 2, 6.6, (4+8j), True, False]

# %%
a[-8:-1 : 1]
# Out:
# ['bhavana', 'manisha', 2, 6.6, (4+8j), True, False]

# %%
a[-8:-1 : 2]
# Out:
# ['bhavana', 2, (4+8j), False]

# %%
a[-8:-1 : -1]
# Out:
# []

# %% [markdown]
# - list function

# %% [markdown]
# - len()

# %%
a
# Out:
# ['bhavana', 'manisha', 2, 6.6, (4+8j), True, False, 'ravi']

# %%
len(a)
# Out:
# 8

# %%
b="bha vana"

len(b)
# Out:
# 8

# %% [markdown]
# - min()

# %%
c=[1,7,9,99,45,87,234,123,7.8,0]


min(c)
# Out:
# 0

# %% [markdown]
# - max()

# %%
max(c)
# Out:
# 234

# %% [markdown]
# - sum()

# %%
sum(c)
# Out:
# 612.8

# %% [markdown]
# - sorted

# %%
c
# Out:
# [1, 7, 9, 99, 45, 87, 234, 123, 7.8, 0]

# %%
sorted(c)
# Out:
# [0, 1, 7, 7.8, 9, 45, 87, 99, 123, 234]

# %%
sorted(c,reverse=True)
# Out:
# [234, 123, 99, 87, 45, 9, 7.8, 7, 1, 0]

# %% [markdown]
# - list methods
#
# - append()/ insert()/extend()
#
# - pop()/remove()

# %% [markdown]
# - append()

# %% [markdown]
# it was added at the end of list

# %%
a
# Out:
# ['bhavana', 'manisha', 2, 6.6, (4+8j), True, False, 'ravi']

# %%
a.append("ai&ml")

# %%
a
# Out:
# ['bhavana', 'manisha', 2, 6.6, (4+8j), True, False, 'ravi', 'ai&ml']

# %%
a.append(99)

# %%
a
# Out:
# ['bhavana', 'manisha', 2, 6.6, (4+8j), True, False, 'ravi', 'ai&ml', 99]

# %% [markdown]
# - extend

# %%
a.extend(["python","sql","ML"])

# %%
a
# Out:
# ['bhavana',
#  'manisha',
#  2,
#  6.6,
#  (4+8j),
#  True,
#  False,
#  'ravi',
#  'ai&ml',
#  99,
#  'python',
#  'sql',
#  'ML']

# %% [markdown]
# - insert()

# %%
a.insert(1,"DL")

# %%
a
# Out:
# ['bhavana',
#  'DL',
#  'manisha',
#  2,
#  6.6,
#  (4+8j),
#  True,
#  False,
#  'ravi',
#  'ai&ml',
#  99,
#  'python',
#  'sql',
#  'ML']

# %% [markdown]
# - pop()

# %%
a
# Out:
# ['bhavana',
#  'DL',
#  'manisha',
#  2,
#  6.6,
#  (4+8j),
#  True,
#  False,
#  'ravi',
#  'ai&ml',
#  99,
#  'python',
#  'sql',
#  'ML']

# %%
a.pop()
# Out:
# 'ML'

# %%
a
# Out:
# ['bhavana',
#  'DL',
#  'manisha',
#  2,
#  6.6,
#  (4+8j),
#  True,
#  False,
#  'ravi',
#  'ai&ml',
#  99,
#  'python',
#  'sql']

# %%
a.pop()
# Out:
# 'sql'

# %%
a
# Out:
# ['bhavana',
#  'DL',
#  'manisha',
#  2,
#  6.6,
#  (4+8j),
#  True,
#  False,
#  'ravi',
#  'ai&ml',
#  99,
#  'python']

# %%
a.pop(1)
# Out:
# 'DL'

# %%
a
# Out:
# ['bhavana',
#  'manisha',
#  2,
#  6.6,
#  (4+8j),
#  True,
#  False,
#  'ravi',
#  'ai&ml',
#  99,
#  'python']

# %%
a.pop(-1)
# Out:
# 'python'

# %%
a
# Out:
# ['bhavana', 'manisha', 2, 6.6, (4+8j), True, False, 'ravi', 'ai&ml', 99]

# %% [markdown]
# - remove()

# %%
a.remove("ai&ml")

# %%
a
# Out:
# ['bhavana', 'manisha', 2, 6.6, (4+8j), True, False, 'ravi', 99]

# %%
a.remove(99)

# %%
a
# Out:
# ['bhavana', 'manisha', 2, 6.6, (4+8j), True, False, 'ravi']

# %% [markdown]
# - clear()

# %%
my_list=['R',1,6,9,0]

my=my_list.copy()

# %%
my
# Out:
# ['R', 1, 6, 9, 0]

# %%
my_list
# Out:
# ['R', 1, 6, 9, 0]

# %%
my_list.clear()

# %%
my_list
# Out:
# []

# %% [markdown]
# del

# %%
my
# Out:
# ['R', 1, 6, 9, 0]

# %%
del my[0]

# %%
my
# Out:
# [1, 6, 9, 0]

# %%
del my

# %%
my
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[72], line 1
# ----> 1 my
#
# NameError: name 'my' is not defined

# %% [markdown]
# count()

# %%
a
# Out:
# ['bhavana', 'manisha', 2, 6.6, (4+8j), True, False, 'ravi']

# %%
a.extend([1,3,5,1,3,5,9,8,5,8])

# %%
a
# Out:
# ['bhavana',
#  'manisha',
#  2,
#  6.6,
#  (4+8j),
#  True,
#  False,
#  'ravi',
#  1,
#  3,
#  5,
#  1,
#  3,
#  5,
#  9,
#  8,
#  5,
#  8]

# %%
a.count(1)
# Out:
# 3

# %%
a.count(8)
# Out:
# 2

# %% [markdown]
# - index()

# %%
a
# Out:
# ['bhavana',
#  'manisha',
#  2,
#  6.6,
#  (4+8j),
#  True,
#  False,
#  'ravi',
#  1,
#  3,
#  5,
#  1,
#  3,
#  5,
#  9,
#  8,
#  5,
#  8]

# %%
a.index("bhavana")
# Out:
# 0

# %%
a.index(True)
# Out:
# 5
