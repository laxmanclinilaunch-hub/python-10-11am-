# %% [markdown]
# Numeric -
# Numeric variables take values which are numbers like 9, 3.14, 0, Inf

# %% [markdown]
# - integer:
#
#      - example 1,7,9,5,
#
# - float (decimals):
#     - 0.9,0.6,1.7,3.15
#
#
# - complex_numbers:
#    - 6+8j, 9+3j

# %% [markdown]
# - Arthmetic operator
#
#  -      + , - ,  * , /,  //, %, **

# %%
# addition

8+6
# Out:
# 14

# %%
6+7
# Out:
# 13

# %%
# subtraction
12-5
# Out:
# 7

# %%
5-2
# Out:
# 3

# %%
# multiplication

5*2
# Out:
# 10

# %%
10*3
# Out:
# 30

# %%
# divion

3/2
# Out:
# 1.5

# %%
7/2
# Out:
# 3.5

# %%
25/5
# Out:
# 5.0

# %%
# floor divion

3//2
# Out:
# 1

# %%
7//2
# Out:
# 3

# %%
25//5
# Out:
# 5

# %%
# exponenational

4**2
# Out:
# 16

# %% [markdown]
# what is default data type of output while doing mathematical operations
#
# float except adding , sub, multiplication

# %% [markdown]
# - # division(/) and floor divion(//)   and modules (%)

# %%
3/4
# Out:
# 0.75

# %%
3//4
# Out:
# 0

# %%
4/5
# Out:
# 0.8

# %%
4//5
# Out:
# 0

# %%
5%3
# Out:
# 2

# %%
7%6
# Out:
# 1

# %%
12%4
# Out:
# 0

# %%
10%100
# Out:
# 10

# %%
3%4
# Out:
# 3

# %%
8%12
# Out:
# 8

# %% [markdown]
# - variables ?
#
#     - it is a fixed name
#
#     - to store the data and retrives the data
#
#     it can store the information of text , numbers , string ,boolean etc

# %% [markdown]
# - Rules for delaring  the variable name :

# %% [markdown]
# - 1. Variable name must be start with either letters (alphbet) or underscore (_)

# %%
a=6

print(a)
# Out:
# 6

# %%
_a=9

_a
# Out:
# 9

# %% [markdown]
# - 2.variable name can't start with number

# %%
9="ravi"
# Out:
#   Cell In[26], line 1
#     9="ravi"
#     ^
# SyntaxError: cannot assign to literal here. Maybe you meant '==' instead of '='?

# %%
_9="ravi"
_9
# Out:
# 'ravi'

# %%
a9="ravi"

a9
# Out:
# 'ravi'

# %% [markdown]
# 3. variable name in python are case sentive AND for best usage use small letters only

# %%
bd=156


print(BD)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[29], line 4
#       1 bd=156
#       2
#       3
# ----> 4 print(BD)
#
# NameError: name 'BD' is not defined

# %% [markdown]
# - 4. variable names may consist of letters, underscore and numbers

# %%
a7=89

a7
# Out:
# 89

# %%
_7="bhavana"

_7
# Out:
# 'bhavana'

# %%
a7_="manisha"

a7_
# Out:
# 'manisha'

# %%
_7a="manisha2"

_7a
# Out:
# 'manisha2'

# %% [markdown]
# - 5. variable names can't use python keywords

# %%
import keyword

keyword.kwlist
# Out:
# ['False',
#  'None',
#  'True',
#  'and',
#  'as',
#  'assert',
#  'async',
#  'await',
#  'break',
#  'class',
#  'continue',
#  'def',
#  'del',
#  'elif',
#  'else',
#  'except',
#  'finally',
#  'for',
#  'from',
#  'global',
#  'if',
#  'import',
#  'in',
#  'is',
#  'lambda',
#  'nonlocal',
#  'not',
#  'or',
#  'pass',
#  'raise',
#  'return',
#  'try',
#  'while',
#  'with',
#  'yield']

# %%
True=8

True
# Out:
#   Cell In[35], line 1
#     True=8
#     ^
# SyntaxError: cannot assign to True

# %%
true=900

true
# Out:
# 900

# %% [markdown]
# - 2. Comparision operators
#
#   - these operators will allow us to compare variables then give the output a Boolean value (True, False)

# %% [markdown]
# - < , > , <=,   >=,  ==,    !=

# %%
a=5
b=1

a>b
# Out:
# True

# %%
a=5
b=1

a<b
# Out:
# False

# %%
a==6
# Out:
# False

# %%
b==1
# Out:
# True

# %%
a!=0
# Out:
# True

# %%
2!=0
# Out:
# True

# %%
2==0
# Out:
# False

# %%
x=3
y=2

x>=y
# Out:
# True

# %%
p=4

q=4

p>=q
# Out:
# True

# %% [markdown]
# 3. Logical operators:
#
#     - and : if both conditions are true , it returns true
#
#
#     - or : either any one of the condition are true , then returns true
#
#
#     - not : opposite of original

# %% [markdown]
# - and

# %%
x=45

print(x)
# Out:
# 45

# %%
x <6 and x<10
# Out:
# False

# %%
x>6 and x<10
# Out:
# False

# %%
x>6 and x>10
# Out:
# True

# %% [markdown]
# - or

# %%
x>6 or x>10
# Out:
# True

# %%
x>6 or x<10
# Out:
# True

# %%
x<6 or x<10
# Out:
# False

# %% [markdown]
# - not

# %%
x<6 or x<10
# Out:
# False

# %%
not(x<6 or x<10 )
# Out:
# True

# %%
not(x>6 and x<10)
# Out:
# True

# %% [markdown]
# - Membership operator:
#
#     -   Membership operators are used  to test if a sequence is presented in an object
#
#
#     - in , not in

# %%
y=[3,8,9,1,"ravi",4+8j,343]


print (x in y )
# Out:
# False

# %%
9 in y
# Out:
# True

# %%
x not in y
# Out:
# True

# %%
"ravi" in y
# Out:
# True

# %% [markdown]
# - assignment operators:
#
#        =, -=,  += , *= , /= , %= , //= , **=

# %%
x="banana"

y="orange"

z="cherry"


print(x)

print(y)

print(z)
# Out:
# banana
# orange
# cherry

# %%
x,y,z="banana" ,"orange" ,"cherry"


print(x)

print(y)

print(z)
# Out:
# banana
# orange
# cherry

# %%
x=10
x+=5


print(x)
# Out:
# 15

# %%
x=10

x-=3

print(x)
# Out:
# 7

# %%
x=10

x*=4

print(x)
# Out:
# 40

# %%
x=10
x/=3

print(x)
# Out:
# 3.3333333333333335

# %%
x=10

x//=3

print(x)
# Out:
# 3

# %%
x=10

x%=3

print(x)
# Out:
# 1

# %%
x=10

x**=3

print(x)
# Out:
# 1000
