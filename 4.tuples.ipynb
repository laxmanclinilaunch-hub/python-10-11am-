# %% [markdown]
# # Tuples:
#
# - the construction of tuples , we generally use ( ) ,with element separated by comma
#
# - it is similar to lists
#
# - tuples are immutable

# %%
a=("bhavana","manisha",2,8,9,6,True,False,5+8j)

a
# Out:
# ('bhavana', 'manisha', 2, 8, 9, 6, True, False, (5+8j))

# %%
type(a)
# Out:
# tuple

# %% [markdown]
# is it   paranthenses ( ) mandatory for creating tuple  ?
#
# No, just it is optional

# %%
b="bhavana","manisha",2,8,9,6,True,False,5+8j

b
# Out:
# ('bhavana', 'manisha', 2, 8, 9, 6, True, False, (5+8j))

# %%
type(b)
# Out:
# tuple

# %%
a
# Out:
# ('bhavana', 'manisha', 2, 8, 9, 6, True, False, (5+8j))

# %% [markdown]
# Tuple indexing
#
# +ve/ forward index
# it start from left to right
#
# it start from 0,1,2,3,....

# %%
a[0]
# Out:
# 'bhavana'

# %%
a[1]
# Out:
# 'manisha'

# %%
a[8]
# Out:
# (5+8j)

# %%
a[6]
# Out:
# True

# %% [markdown]
# - ve / backward index:
#    - it start from right to left
#    - it starting from -1,-2,-3,....

# %%
a
# Out:
# ('bhavana', 'manisha', 2, 8, 9, 6, True, False, (5+8j))

# %%
a[-1]
# Out:
# (5+8j)

# %%
a[-9]
# Out:
# 'bhavana'

# %%
a[-3]
# Out:
# True

# %%
a[-6]
# Out:
# 8

# %% [markdown]
# # slicing witout step
#
# +ve /forward slicing:
# - it start from left to right
#
# - it has start , stop(n-1)

# %%
a
# Out:
# ('bhavana', 'manisha', 2, 8, 9, 6, True, False, (5+8j))

# %%
a[ 0:2 ]
# Out:
# ('bhavana', 'manisha')

# %%
a[ 1:4 ]
# Out:
# ('manisha', 2, 8)

# %% [markdown]
# - -ve/backward slicing:withoutstep
#    - it start from right to left
#     - it has start n stop (n-1)

# %%
a
# Out:
# ('bhavana', 'manisha', 2, 8, 9, 6, True, False, (5+8j))

# %%
a[ -9:-7 ]
# Out:
# ('bhavana', 'manisha')

# %%
a[ -3:-1 ]
# Out:
# (True, False)

# %%
a[ -7:-3 ]
# Out:
# (2, 8, 9, 6)

# %% [markdown]
# - +ve and -ve slicing with step

# %%
a
# Out:
# ('bhavana', 'manisha', 2, 8, 9, 6, True, False, (5+8j))

# %%
a[ : : 2]
# Out:
# ('bhavana', 2, 9, True, (5+8j))

# %%
a[1:4 :2 ]
# Out:
# ('manisha', 8)

# %%
a
# Out:
# ('bhavana', 'manisha', 2, 8, 9, 6, True, False, (5+8j))

# %%
a[0:9:-2]
# Out:
# ()

# %%
a[::-1]
# Out:
# ((5+8j), False, True, 6, 9, 8, 2, 'manisha', 'bhavana')

# %%
a[::-2]
# Out:
# ((5+8j), True, 9, 2, 'bhavana')

# %%
a
# Out:
# ('bhavana', 'manisha', 2, 8, 9, 6, True, False, (5+8j))

# %%
a[ -9:-6 :1]
# Out:
# ('bhavana', 'manisha', 2)

# %%
a[ -7:-3 :1 ]
# Out:
# (2, 8, 9, 6)

# %%
a[-9:-6:-1]
# Out:
# ()

# %%
a[ -7:-3 :-1 ]
# Out:
# ()

# %% [markdown]
# - Tuple methods

# %% [markdown]
# - index()

# %%
a
# Out:
# ('bhavana', 'manisha', 2, 8, 9, 6, True, False, (5+8j))

# %%
a.index("bhavana")
# Out:
# 0

# %%
a.index("manisha")
# Out:
# 1

# %%
a.index(6)
# Out:
# 5

# %% [markdown]
# - count()

# %%
c=1,5,9,1,5,8,9,2,"manisha","bhavana",2,1

c
# Out:
# (1, 5, 9, 1, 5, 8, 9, 2, 'manisha', 'bhavana', 2, 1)

# %%
c.count(1)
# Out:
# 3

# %%
c.count(5)
# Out:
# 2

# %% [markdown]
# - zip()
#   - it takes multiple lists as arugument and zips them
#
#   - it returns a list of n-paired tuples

# %%
city_list=["delhi","patna","hyd","guwahati"]


river_list=["yamuna","ganga",'musi',"brahmaputra"]

# %%
d=zip(city_list,river_list)

# %%
list(d)
# Out:
# [('delhi', 'yamuna'),
#  ('patna', 'ganga'),
#  ('hyd', 'musi'),
#  ('guwahati', 'brahmaputra')]

# %% [markdown]
# - when to use tuple:
#     - to be honest tuples are not used as often as lists programing , where ever necessary of immutable then we have to use tuples
