# %% [markdown]
# - Dict:
#    - What is Dict?
#       - Mapping of one to one relationship between key and value pair is called dict
#       - dictionary object is constructed by using curly braces { key1:value1 , key2:value2, key3:value3}
#
#     - what is mapping:
#        - mapping means collection of objects

# %%
marvel_dict={"name":"thor","place":"asgard","weapon":"hammer","super_heros":["iron_man","captian_america"]}

marvel_dict
# Out:
# {'name': 'thor',
#  'place': 'asgard',
#  'weapon': 'hammer',
#  'super_heros': ['iron_man', 'captian_america']}

# %%
marvel_dict["name"]
# Out:
# 'thor'

# %%
marvel_dict["super_heros"]
# Out:
# ['iron_man', 'captian_america']

# %% [markdown]
# - methods

# %% [markdown]
# - keys()

# %%
marvel_dict.keys()
# Out:
# dict_keys(['name', 'place', 'weapon', 'super_heros'])

# %%
list(marvel_dict.keys())
# Out:
# ['name', 'place', 'weapon', 'super_heros']

# %% [markdown]
# - values()

# %%
marvel_dict.values()
# Out:
# dict_values(['thor', 'asgard', 'hammer', ['iron_man', 'captian_america']])

# %%
list(marvel_dict.values())
# Out:
# ['thor', 'asgard', 'hammer', ['iron_man', 'captian_america']]

# %% [markdown]
# - items()

# %%
marvel_dict.items()
# Out:
# dict_items([('name', 'thor'), ('place', 'asgard'), ('weapon', 'hammer'), ('super_heros', ['iron_man', 'captian_america'])])

# %%
list(marvel_dict.items())
# Out:
# [('name', 'thor'),
#  ('place', 'asgard'),
#  ('weapon', 'hammer'),
#  ('super_heros', ['iron_man', 'captian_america'])]

# %% [markdown]
# - get()

# %%
marvel_dict.get("place","that was not existed")
# Out:
# 'asgard'

# %%
marvel_dict.get("zoo","that was not existed")
# Out:
# 'that was not existed'

# %%
marvel_dict.get("place")
# Out:
# 'asgard'

# %%
marvel_dict.get("zoo")

# %% [markdown]
# # adding new values

# %%
marvel_dict["designation"]="Dentist"

# %%
marvel_dict
# Out:
# {'name': 'thor',
#  'place': 'asgard',
#  'weapon': 'hammer',
#  'super_heros': ['iron_man', 'captian_america'],
#  'designation': 'Dentist'}

# %% [markdown]
# - update()

# %%
marvel_dict.update({"salary":"12,00,000","name2":"bhavana%manisha"})

# %%
marvel_dict
# Out:
# {'name': 'thor',
#  'place': 'asgard',
#  'weapon': 'hammer',
#  'super_heros': ['iron_man', 'captian_america'],
#  'designation': 'Dentist',
#  'salary': '12,00,000',
#  'name2': 'bhavana%manisha'}

# %% [markdown]
# - len()

# %%
len(marvel_dict)
# Out:
# 7

# %% [markdown]
# - copy()

# %%
d1={"name":"manish&bhavana","B.tech":["python","ML","DL","GENAI","agenticAI","mlops"]}


d1
# Out:
# {'name': 'manish&bhavana',
#  'B.tech': ['python', 'ML', 'DL', 'GENAI', 'agenticAI', 'mlops']}

# %%
d2=d1.copy()

# %%
d2
# Out:
# {'name': 'manish&bhavana',
#  'B.tech': ['python', 'ML', 'DL', 'GENAI', 'agenticAI', 'mlops']}

# %% [markdown]
# - removing different methods

# %%
del d1['name']

# %%
d1
# Out:
# {'B.tech': ['python', 'ML', 'DL', 'GENAI', 'agenticAI', 'mlops']}

# %%
d2
# Out:
# {'name': 'manish&bhavana',
#  'B.tech': ['python', 'ML', 'DL', 'GENAI', 'agenticAI', 'mlops']}

# %%
d2.pop("name")
# Out:
# 'manish&bhavana'

# %%
d2
# Out:
# {'B.tech': ['python', 'ML', 'DL', 'GENAI', 'agenticAI', 'mlops']}

# %% [markdown]
# - updating key

# %%
d2["Skills"]=d2.pop("B.tech")

# %%
d2
# Out:
# {'Skills': ['python', 'ML', 'DL', 'GENAI', 'agenticAI', 'mlops']}

# %%
d1
# Out:
# {'B.tech': ['python', 'ML', 'DL', 'GENAI', 'agenticAI', 'mlops']}

# %% [markdown]
# - clear()

# %%
d1.clear()

# %%
d1
# Out:
# {}

# %% [markdown]
# - del

# %%
del d2

# %%
d2
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[36], line 1
# ----> 1 d2
#
# NameError: name 'd2' is not defined

# %%
# we can't set & list as key


a={"ravi":1}

b={(1,23):"ravi"}

# %%
c={[12,56]:"ravi"}   # we can't use list as key but we can use list as value
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# Cell In[42], line 1
# ----> 1 c={[12,56]:"ravi"}   # we can't use list as key but we can use list as value
#
# TypeError: unhashable type: 'list'

# %%
c={"ravi":[12,78]}

# %%
se={1,4,9}

se
# Out:
# {1, 4, 9}
