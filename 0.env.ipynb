# %% [markdown]
# - virtual env setup
#
#
# - method -1
#
#
# step1:
# conda create -n python10am python=3.12 -y
#
# step2:
# conda activate python10am
#
#
# - method-2
#
# step-1:
# python -m venv venv
#
# step-2:
# venv\Scripts\activate
